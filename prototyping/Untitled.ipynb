# %%
ket0 = [1 0]
# Out:
# FieldError: type Array has no field `T`, available fields: `ref`, `size`
#
# Stacktrace:
#  [1] getproperty(x::Matrix{Int64}, f::Symbol)
#    @ Base ./Base_compiler.jl:54
#  [2] top-level scope
#    @ In[2]:1
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
